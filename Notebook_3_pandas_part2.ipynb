# %%
#pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("placement.csv",index_col=0,nrows=100,on_bad_lines='skip')
#index_col changes the index for the dataset
df       
# OR warn when skipping bad lines
#df = pd.read_csv("data.csv", on_bad_lines='warn')

#for the dates for changing in datetime[64] from object or string
#df = pd.read_csv("data.csv", parse_dates=['date'])
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
df = pd.read_csv("placement.csv",dtype=object,skiprows=[1,3]).info() # or float and skiprows removes the given rows
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  98 non-null     object
#  1   cgpa        98 non-null     object
#  2   iq          98 non-null     object
#  3   placement   98 non-null     object
# dtypes: object(4)
# memory usage: 3.2+ KB

# %%
#df["cgpa"][1] #accessing using index

# %%
df = pd.read_csv("placement.csv",usecols=["cgpa","iq"])
df.head()

# %%
df.dtypes
# Out:
# Unnamed: 0    object
# iq            object
# placement     object
# dtype: object

# %%
df=pd.read_csv("placement.csv",dtype={'placements':int,'cgpa':float})
df["cgpa"]
# Out:
# 0     6.8
# 1     5.9
# 2     5.3
# 3     7.4
# 4     5.8
#      ...
# 95    4.3
# 96    4.4
# 97    6.7
# 98    6.3
# 99    6.2
# Name: cgpa, Length: 100, dtype: float64

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# cgpa          float64
# iq            float64
# placement       int64
# dtype: object

# %%
#test=pd.read_csv("Test1.csv",sep=';')
#test

# %%
#df["cgpa"].unique()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# cgpa          0
# iq            0
# placement     0
# dtype: int64

# %%
#df.describe()

# %%
#df["cgpa"].value_counts()

# %%
from io import StringIO, BytesIO

# %%
data = ('col1,col2,col3\n'
            'x,y,1\n'
            'a,b,2\n'
            'c,d,3')

# %%
type(data)
# Out:
# str

# %%
pd.read_csv(StringIO(data))
# Out:
#   col1 col2  col3
# 0    x    y     1
# 1    a    b     2
# 2    c    d     3

# %%
#Text Data
data='a,b\n"hello, \\"John\\", nice to see you",5'
pd.read_csv(StringIO(data),escapechar='\\',names=['sno','first','second'],index_col='sno') 
#index col is used for chnaging the index of dataset and names are used for naming the columns
# Out:
#                                first  second
# sno
# a                                  b     NaN
# hello, "John", nice to see you     5     NaN

# %%
#pd.read_csv("https://download.bls.gov/pub/time.series/cu/cu.item", sep='\t')

# %%
d= pd.read_csv("cu.item", sep='\t')
d
# Out:
#     item_code                                          item_name  \
# 0         AA0                               All items - old base
# 1        AA0R  Purchasing power of the consumer dollar - old ...
# 2         SA0                                          All items
# 3        SA0E                                             Energy
# 4       SA0L1                                All items less food
# ..        ...                                                ...
# 395   SSEA011                                  College textbooks
# 396   SSEE041                                        Smartphones
# 397  SSFV031A           Food at elementary and secondary schools
# 398   SSGE013                                 Infants' equipment
# 399   SSHJ031                                 Infants' furniture
#
#      display_level selectable  sort_sequence
# 0                0          T              2
# 1                0          T            400
# 2                0          T              1
# ...

# %% [markdown]
# #**Converters** used for converting to short names

# %%
def rename(name):
    if name=="Royal Challengers Banglore":
        return "RCB"
    else:
        return name

# %%
rename("Royal Challengers Banglore")
# Out:
# 'RCB'

# %%
#pd.read_csv("IPL Matches.csv",converters={'team1':rename})

# %%
#na_values for NaN or used for null values or not present
#pd.read_csv("aug_train.csv",na_values=['Male']) or '-'

# %%
#Loading Data in chunks
pp= pd.read_csv('aug_train.csv',chunksize=5000)

# %%
for chunks in pp:
    print(chunks.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (4158, 14)
